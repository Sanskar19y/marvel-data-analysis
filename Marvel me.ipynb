# %% [markdown]
# # Marvel DC superheros Anaylsis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Marvel=pd.read_csv('charcters_stats.csv')

# %%
Marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
Marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          611 non-null    object
#  1   Alignment     608 non-null    object
#  2   Intelligence  611 non-null    int64
#  3   Strength      611 non-null    int64
#  4   Speed         611 non-null    int64
#  5   Durability    611 non-null    int64
#  6   Power         611 non-null    int64
#  7   Combat        611 non-null    int64
#  8   Total         611 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %%
Marvel.shape
# Out:
# (611, 9)

# %%
Marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
#Lets separate heroes and villains and then go ahead

# %%
Marvel_H=Marvel[Marvel['Alignment']=='good']

# %%
Marvel_V=Marvel[Marvel['Alignment']=='bad']

# %%
#Among superheros

# %%
Marvel_H.sort_values(by=['Intelligence'],ascending=False).head(5)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 306          Jean Grey      good           100        80     67         100
# 123         Brainiac 5      good           100        10     23          28
# 433            Phoenix      good           100        80     67         100
# 417               Nova      good           100        85     67         101
#
#      Power  Combat  Total
# 361    100      85    581
# 306    100      70    517
# 123     60      32    253
# 433    100      70    517
# 417    100      85    538

# %%
max_intelligence=Marvel_H[Marvel_H['Intelligence']==100]

# %%
#These many superheroes with 100 Intelligence.....

# %%
max_intelligence
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 24             Ant-Man      good           100        10     23          28
# 61              Batman      good           100        18     27          42
# 123         Brainiac 5      good           100        10     23          28
# 138     Captain Marvel      good           100       100     67          95
# 198     Doctor Strange      good           100        10     12          84
# 299           Iron Man      good           100        85     58          85
# 306          Jean Grey      good           100        80     67         100
# 361  Martian Manhunter      good           100       100     96         100
# 384   Mister Fantastic      good           100        10     18          70
# 417               Nova      good           100        85     67         101
# 433            Phoenix      good           100        80     67         100
# ...

# %%
Marvel_H.sort_values(by=['Combat'],ascending=False).head(5)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 36         Ares      good            75        82     35          80     62
# 298   Iron Fist      good            75        23     35          42     43
# 597   Wolverine      good            55        32     38         100     44
# 58   Batgirl IV      good            69        12     27          56     42
# 61       Batman      good           100        18     27          42     37
#
#      Combat  Total
# 36      101    435
# 298     100    318
# 597     100    369
# 58      100    306
# 61      100    324

# %%
Marvel_H.sort_values(by=['Power'],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# ...

# %%
max_power_H=Marvel_H.sort_values(by=['Total'],ascending=False).head(5)

# %%
max_power_H
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
plt.figure(figsize=(10,6))
plt.bar(max_power_H['Name'],max_power_H['Total'],color='orange')
# Out:
# <BarContainer object of 5 artists>

# %%
#For villains

# %%
Marvel_V.sort_values(by=['Speed'],ascending=False)[0:10]
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610             Zoom       bad            50        10    100          28
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 242      General Zod       bad            94       100     96         100
# 171  Cyborg Superman       bad            75        93     92         100
# 84        Black Adam       bad            88       100     92         100
# 203         Dormammu       bad            88        95     83         100
# 205              Ego       bad            88        80     83          99
# 218    Fallen One II       bad            88        85     83         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# ...

# %%
Marvel_V.sort_values(by=['Total'],ascending=False).head(5)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
villains_max_power=Marvel_V.sort_values(by=['Total'],ascending=False).head(5)

# %%
plt.figure(figsize=(10,6))
plt.bar(villains_max_power['Name'],villains_max_power['Total'],color='blue')
plt.xlabel('villains')
plt.ylabel('Power')
# Out:
# Text(0, 0.5, 'Power')

# %%
#lets check distribution of speed of superheros

# %%
plt.figure(figsize=(8,5))
plt.hist(Marvel_H['Speed'],color='pink')
plt.xlabel('Speed')
plt.ylabel('count')
plt.title('Speed distribution')
# Out:
# Text(0.5, 1.0, 'Speed distribution')

# %%
#lets check distribution of Intelligence of superheros

# %%
plt.figure(figsize=(8,5))
plt.hist(Marvel_H['Intelligence'],color='purple')
plt.xlabel('Intelligence')
plt.ylabel('count')
plt.title('Intelligence Graph')
# Out:
# Text(0.5, 1.0, 'Intelligence Graph')

# %%
#Being a Iron man fan

# %%
Marvel[Marvel['Name']=='Iron Man']
# Out:
#          Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 299  Iron Man      good           100        85     58          85    100
#
#      Combat  Total
# 299      64    492

# %% [markdown]
# # Great Work
